# %% [markdown]
# <a href="https://colab.research.google.com/github/LuizMiron/analise-de-dados-com-colab/blob/main/Teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade gspread
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gspread in /usr/local/lib/python3.7/dist-packages (3.4.2)
# Collecting gspread
#   Downloading gspread-5.4.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from gspread) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from gspread) (0.4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.9)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (57.4.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.0.4)
# Installing collected packages: gspread
#   Attempting uninstall: gspread
#     Found existing installation: gspread 3.4.2
#     Uninstalling gspread-3.4.2:
#       Successfully uninstalled gspread-3.4.2
# Successfully installed gspread-5.4.0

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials
from google.auth import default

creds, _ = default()

#This only needs to be done once per notebook.
gc = gspread.authorize(creds)

# %% [markdown]
# # Nova seção

# %%
spreasheet = gc.open("Vendas-Dez")

# %%
pagina = spreasheet.sheet1

pagina.row_values(1)
# Out:
# ['Código Venda',
#  'Data',
#  'ID Loja',
#  'Produto',
#  'Quantidade',
#  'Valor Unitário',
#  'Valor Final']

# %%
import pandas as pd

# %%
vendas = pd.DataFrame(pagina.get_all_records())

# %%
vendas.head()
# Out:
#    Código Venda       Data             ID Loja          Produto  Quantidade  \
# 0         65014  12/1/2019    Shopping Morumbi   Sunga Listrado           5
# 1         65014  12/1/2019    Shopping Morumbi  Casaco Listrado           1
# 2         65016  12/1/2019   Iguatemi Campinas  Sapato Listrado           2
# 3         65016  12/1/2019   Iguatemi Campinas           Casaco           1
# 4         65017  12/1/2019  Shopping SP Market       Gorro Liso           3
#
#   Valor Unitário Valor Final
# 0      R$ 114,00   R$ 570,00
# 1      R$ 269,00   R$ 269,00
# 2      R$ 363,00   R$ 726,00
# 3      R$ 250,00   R$ 250,00
# 4       R$ 92,00   R$ 276,00

# %%
vendas.query("Quantidade==4")
# Out:
#       Código Venda        Data                           ID Loja  \
# 10           65020   12/1/2019                  Shopping Morumbi
# 22           65031   12/1/2019        Shopping Center Interlagos
# 26           65034   12/1/2019               Shopping Vila Velha
# 37           65040   12/1/2019                  Shopping Morumbi
# 54           65053   12/1/2019  Shopping Center Leste Aricanduva
# ...            ...         ...                               ...
# 7075         69986  12/26/2019                 Shopping Eldorado
# 7077         69987  12/26/2019               Bourbon Shopping SP
# 7078         69991  12/26/2019        Center Shopping Uberlândia
# 7083         69995  12/26/2019      Novo Shopping Ribeirão Preto
# 7085         69996  12/26/2019        Center Shopping Uberlândia
#
#                     Produto  Quantidade Valor Unitário  Valor Final
# 10        Pulseira Listrado           4       R$ 79,00    R$ 316,00
# 22                Meia Liso           4       R$ 38,00    R$ 152,00
# 26       Camisa Gola V Liso           4      R$ 118,00    R$ 472,00
# 37            Gorro Estampa           4       R$ 93,00    R$ 372,00
# 54    Camisa Gola V Estampa           4      R$ 118,00    R$ 472,00
# ...                     ...         ...            ...          ...
# 7075          Cueca Estampa           4       R$ 66,00    R$ 264,00
# 7077        Bermuda Estampa           4      R$ 169,00    R$ 676,00
# 7078                Mochila           4      R$ 270,00  R$ 1.080,00
# 7083                Mochila           4      R$ 270,00  R$ 1.080,00
# 7085                Mochila           4      R$ 270,00  R$ 1.080,00
#
# [577 rows x 7 columns]
